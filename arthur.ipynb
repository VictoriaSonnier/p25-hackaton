# %%
#board de la forme : board=[1,6,2,7,8,"-",4,5,3]

def adjacence(i): #case adjacentes à la case i dans [0,8]
    if i==0:
        return [1,3]
    elif i==1:
        return [0,2,4]
    elif i==2:
        return [1,5]
    elif i==3:
        return [0,4,6]
    elif i==4:
        return [1,3,5,7]
    elif i==5:
        return [2,4,8]
    elif i==6:
        return [3,7]
    elif i==7:
        return [4,6,8]
    elif i==8:
        return [5,7]

def case_vide(board): #renvoie la case vide du board
    for i in range(9):
        if board[i]=="-":
            return i

def echange_case(board,i,j): #i et j sont deux cases adjacentes
    board[i],board[j]=board[j],board[j]
    return board

board_resolu=[1,2,3,4,5,6,7,8,"-"]

def Dijkstra(board):
